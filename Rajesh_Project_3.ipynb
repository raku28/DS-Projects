# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns  
# %matplotlib inline
import scipy.stats as stats
from scipy.stats import norm

# %%
from IPython.display import Image
Image(filename='Capture12.JPG',width=500,height=500)

# %% [markdown]
# #### P1) What is the probability that a randomly chosen player would suffer an injury?

# %%
Total_Player_Injured=145
Total_Player=235
Prob_Suffer_injury = (Total_Player_Injured/Total_Player)*100
print('probability that a randomly chosen player would suffer an injury is %1.1f' % Prob_Suffer_injury +'%')
# Out:
# probability that a randomly chosen player would suffer an injury is 61.7%

# %% [markdown]
#  #### P2) What is the probability that a player is a forward or a winger?

# %%
Total_forward_player=94
Total_winger_player=29
Total_Player=235
A1= (Total_forward_player/Total_Player)
B1= (Total_winger_player/Total_Player)
C1 = (A1+B1)*100
print('probability that a randomly chosen player would be forward or winger is %1.1f' % C1 +'%')
# Out:
# probability that a randomly chosen player would be forward or winger is 52.3%

# %% [markdown]
# #### P3) What is the probability that a randomly chosen player plays in a striker position and has a foot injury?

# %%
Total_Striker_Injured=45
Total_Striker_Player=77
Prob_Suffer_striker_injury = (Total_Striker_Injured/Total_Striker_Player)*100
print('probability that a randomly chosen player would plays in a striker position and has a foot injury is %1.1f' % Prob_Suffer_striker_injury +'%')
# Out:
# probability that a randomly chosen player would plays in a striker position and has a foot injury is 58.4%

# %% [markdown]
# #### P4) What is the probability that a randomly chosen injured player is a striker?

# %%
Total_Striker_Injured=45
Total_Player_Injured=145
D1 = (Total_Striker_Injured/Total_Player_Injured)*100
print('probability that a randomly chosen injured player is a striker is %1.1f' % D1 +'%')
# Out:
# probability that a randomly chosen injured player is a striker is 31.0%

# %% [markdown]
# #### P5) What is the probability that a randomly chosen injured player is either a forward or an attacking midfielder?

# %%
Total_forward_Injured=56
Total_Attack_Midfielder_Injured=24
Total_Player_Injured=145
E1= (Total_forward_Injured/Total_Player_Injured)
F1= (Total_Attack_Midfielder_Injured/Total_Player_Injured)
G1 = (E1+F1)*100
print('probability that a randomly chosen injured player is either a forward or an attacking midfielder is %1.1f' % G1 +'%' )
# Out:
# probability that a randomly chosen injured player is either a forward or an attacking midfielder is 55.2%

# %% [markdown]
# ##### Problem 2
#
# ##### An independent research organization is trying to estimate the probability that an accident at a nuclear power plant will result in radiation leakage. The types of accidents possible at the plant are, fire hazards, mechanical failure, or human error. The research organization also knows that two or more types of accidents cannot occur simultaneously.
#
# ##### According to the studies carried out by the organization, the probability of a radiation leak in case of a fire is 20%, the probability of a radiation leak in case of a mechanical 50%, and the probability of a radiation leak in case of a human error is 10%. The studies also showed the following;
#
# ##### The probability of a radiation leak occurring simultaneously with a fire is 0.1%.
# ##### The probability of a radiation leak occurring simultaneously with a mechanical failure is 0.15%.
# ##### he probability of a radiation leak occurring simultaneously with a human error is 0.12%.

# %% [markdown]
# #### 2.1 What are the probabilities of a fire, a mechanical failure, and a human error respectively?

# %%
Prob_fire=20
Prob_mech=50
Prob_human_err=10
Prob_rad_leak= Prob_fire+Prob_mech+Prob_human_err
A2= (Prob_fire/Prob_rad_leak)*100
B2= (Prob_mech/Prob_rad_leak)*100
C2 = (Prob_human_err/Prob_rad_leak)*100
print('probability of fire %1.1f' % A2 +'%','\nprobability of mechanical failure %1.1f' % B2 +'%','\nprobability of human error %1.1f' % C2 +'%' )
# Out:
# probability of fire 25.0%
# probability of mechanical failure 62.5%
# probability of human error 12.5%

# %% [markdown]
# #### 2.2 What is the probability of a radiation leak?

# %%
p_rad_fire=0.1
p_rad_mech=0.15
p_rad_human_err=0.12
P_rad_leak= p_rad_fire + p_rad_mech + p_rad_human_err
print('probability of a radiation leak is %1.2f' % P_rad_leak +'%')
# Out:
# probability of a radiation leak is 0.37%

# %% [markdown]
# #### 2.3 Suppose there has been a radiation leak in the reactor for which the definite cause is not known. What is the probability that it has been caused by:
#
# #### A Fire.
# #### A Mechanical Failure.
# #### A Human Error

# %%
p_rad_fire=0.1
p_rad_mech=0.15
p_rad_human_err=0.12
P_rad_leak= p_rad_fire + p_rad_mech + p_rad_human_err
D2= (p_rad_fire/P_rad_leak)*100
E2= (p_rad_mech/P_rad_leak)*100
F2 = (p_rad_human_err/P_rad_leak)*100
print('probability of caused by fire %1.2f' % D2 +'%','\nprobability of caused by mechanical failure %1.2f' % E2 +'%','\nprobability of caused by human error %1.2f' % F2 +'%' )
# Out:
# probability of caused by fire 27.03%
# probability of caused by mechanical failure 40.54%
# probability of caused by human error 32.43%

# %% [markdown]
# #### Problem 3:
#
# #### The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information.
#
#
# #### 3.1 What proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm?

# %%
norm.cdf(3.17, 5, 1.5)
print("proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is %1.4f" % (norm.cdf(3.17, 5, 1.5)))
# Out:
# proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is 0.1112

# %%
mu = 5
std = 1.5
snd = stats.norm(mu, std)
#
# Generate 1000 random values between -100, 100
#
x = np.linspace(-100, 100, 1000)
#
# Plot the standard normal distribution for different values of random variable
# falling in the range -100, 100
#
plt.figure(figsize=(7.5,7.5))
plt.plot(x, snd.pdf(x))
plt.fill_between(norm.cdf(3.17, 5, 1.5), norm.pdf(norm.cdf(3.17, 5, 1.5), mu, std), color="r")
plt.xlim(-2, 12)
plt.title('Normal Distribution (Mean = 5, STD = 1.5)', fontsize='15')
plt.xlabel('Values of Random Variable X', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11416\3564201446.py in <module>
#      12 plt.figure(figsize=(7.5,7.5))
#      13 plt.plot(x, snd.pdf(x))
# ---> 14 plt.fill_between(norm.cdf(3.17, 5, 1.5), norm.pdf(norm.cdf(3.17, 5, 1.5), mu, std), color="r")
#      15 plt.xlim(-2, 12)
#      16 plt.title('Normal Distribution (Mean = 5, STD = 1.5)', fontsize='15')
#
# E:\Anaconda\lib\site-packages\matplotlib\pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2553         x, y1, y2=0, where=None, interpolate=False, step=None, *,
#    2554         data=None, **kwargs):
# -> 2555     return gca().fill_between(
#    2556         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
#    2557         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %% [markdown]
# #### 3.2 What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?

# %%
norm.ppf(3.6, 5, 1.5)
print("proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is %1.4f" % (norm.cdf(3.6, 5, 1.5)))
# Out:
# proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is 0.1753

# %% [markdown]
# #### 3.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?

# %%
stats.norm.cdf(5.5,loc=5,scale=1.5)-stats.norm.cdf(5,loc=5,scale=1.5)
print("proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm is %1.4f" % (stats.norm.cdf(5.5,loc=5,scale=1.5)-stats.norm.cdf(5,loc=5,scale=1.5)))
# Out:
# proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm is 0.1306

# %%
cdf_upper_limit = norm(loc = 5 , scale = 1.5).cdf(5.5)
cdf_lower_limit = norm(loc = 5 , scale = 1.5).cdf(5)
 
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
# Out:
# 0.13055865981823633

# %% [markdown]
# #### 3.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
pdf = 1-(stats.norm.cdf(7.5,loc=5,scale=1.5)-stats.norm.cdf(3,loc=5,scale=1.5))
pdf
# Out:
# 0.13900157199868257

# %%
data = np.arange(1,10,0.01)
pdf1 = norm.ppf(3.6, 5, 1.5)
sns.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Problem 4:
#
#
#
# ##### Grades of the final examination in a training course are found to be normally distributed, with a mean of 77 and a standard deviation of 8.5. Based on the given information answer the questions below.
#
#
#
# #### 4.1 What is the probability that a randomly chosen student gets a grade below 85 on this exam?

# %%
mu=77
sigma=8.5
prob_below_85 = norm.cdf(85, mu, sigma)
print("The probability that a randomly chosen student gets a grade below 85 on this exam",round(prob_below_85, 4),)
# Out:
# The probability that a randomly chosen student gets a grade below 85 on this exam 0.8267

# %% [markdown]
# #### 4.2 What is the probability that a randomly selected student scores between 65 and 87

# %%
stats.norm.cdf(87,loc=77,scale=8.5)-stats.norm.cdf(65,loc=77,scale=8.5)
# Out:
# 0.8012869336779058

# %% [markdown]
# #### 4.3 What should be the passing cut-off so that 75% of the students clear the exam?

# %%
norm.ppf(0.75, mu, sigma)
# Out:
# 82.7331628766667

# %% [markdown]
# ### Problem 5:
#
#
#
# #### Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);
#
#
#
# #### 5.1 Earlier experience of Zingaro with this particular client is favorable as the stone surface was found to be of adequate hardness. However, Zingaro has reason to believe now that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?

# %%
df5 = pd.read_csv('Zingaro_Company.csv')
df5
# Out:
#     Unpolished   Treated and Polished
# 0    164.481713            133.209393
# 1    154.307045            138.482771
# 2    129.861048            159.665201
# 3    159.096184            145.663528
# 4    135.256748            136.789227
# ..          ...                   ...
# 70   123.067611            142.293544
# 71   171.822218            140.124092
# 72    88.135994            141.393091
# 73   145.150397            131.370530
# 74   170.854823            144.502647
#
# [75 rows x 2 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unpolished            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %%
df5.describe()
# Out:
#        Unpolished   Treated and Polished
# count    75.000000             75.000000
# mean    134.110527            147.788117
# std      33.041804             15.587355
# min      48.406838            107.524167
# 25%     115.329753            138.268300
# 50%     135.597121            145.721322
# 75%     158.215098            157.373318
# max     200.161313            192.272856

# %% [markdown]
# #### The level of significance (Alpha ) = 0.05.
#
# #### But since the population standard deviation (Sigma) is unknown, we have to use a Tstat test.

# %%
from scipy.stats import ttest_ind
t_stat, p_value = ttest_ind(Unpolished, Treated and Polished)
print("T-statistic value: ", t_stat)  
print("P-Value: ", p_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11416\315217844.py in <module>
#       1 from scipy.stats import ttest_ind
# ----> 2 t_stat, p_value = ttest_ind(Unpolished, Treated and Polished)
#       3 print("T-statistic value: ", t_stat)
#       4 print("P-Value: ", p_value)
#
# NameError: name 'Unpolished' is not defined

# %% [markdown]
# #### Problem 6:
#
#
#
# #### Aquarius health club, one of the largest and most popular cross-fit gyms in the country has been advertising a rigorous program for body conditioning. The program is considered successful if the candidate is able to do more than 5 push-ups, as compared to when he/she enrolled in the program. Using the sample data provided can you conclude whether the program is successful? (Consider the level of Significance as 5%)
#
# #### Note that this is a problem of the paired-t-test. Since the claim is that the training will make a difference of more than 5, the null and alternative hypotheses must be formed accordingly.

# %%
df6 = pd.read_csv('Aquarius_gym.csv')
df6
# Out:
#     Sr no.  Before  After
# 0        1      39     44
# 1        2      25     25
# 2        3      39     39
# 3        4       6     13
# 4        5      40     44
# ..     ...     ...    ...
# 95      96      16     18
# 96      97      19     28
# 97      98      24     28
# 98      99      14     24
# 99     100      30     39
#
# [100 rows x 3 columns]

# %%
#### H0 = candidate is able to do more than 5 push-ups

#### H1 = candidate is able to do only less than 5 push-ups

# %%
df6.drop(columns = 'Sr no.')
# Out:
#     Before  After
# 0       39     44
# 1       25     25
# 2       39     39
# 3        6     13
# 4       40     44
# ..     ...    ...
# 95      16     18
# 96      19     28
# 97      24     28
# 98      14     24
# 99      30     39
#
# [100 rows x 2 columns]

# %%
df6.describe()
# Out:
#            Sr no.      Before       After
# count  100.000000  100.000000  100.000000
# mean    50.500000   26.940000   32.490000
# std     29.011492    8.806357    8.779562
# min      1.000000    3.000000   10.000000
# 25%     25.750000   21.750000   26.000000
# 50%     50.500000   28.000000   34.000000
# 75%     75.250000   32.250000   39.000000
# max    100.000000   47.000000   51.000000

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sr no.  100 non-null    int64
#  1   Before  100 non-null    int64
#  2   After   100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB

# %%
stats.shapiro(df6['Before'])
# Out:
# ShapiroResult(statistic=0.9895846247673035, pvalue=0.6310927867889404)

# %% [markdown]
# #### Here P value is greater than 0.05 so it is normal distribution

# %%
stats.shapiro(df6['After'])
# Out:
# ShapiroResult(statistic=0.9847944974899292, pvalue=0.3069112300872803)

# %% [markdown]
# #### Here P value is greater than 0.05 so it is normal distribution

# %%
# Let's visualize the data
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="ticks")


bins = np.arange(7,70,6)

A = df6['Before'].values
B = df6['After'].values

# Show the results of a linear regression within each dataset
ax1 = sns.histplot(A,bins=bins,label='Before program', color='blue',kde=True)
ax2 = sns.histplot(B,bins=bins,label='After program',kde=True)

plt.pyplot.xlabel('Pushups level')
plt.pyplot.ylabel('Distribution of Pushups levels')
plt.pyplot.legend(bbox_to_anchor=(0.65, 0.95), loc=2, borderaxespad=0.)

plt.pyplot.xlim((1,60))
plt.pyplot.show()

# %%
stats.ttest_rel(df6['Before'], df6['After'])
# Out:
# Ttest_relResult(statistic=-19.322619811082458, pvalue=2.2920419252511966e-35)

# %% [markdown]
# #### P value is gretaer than 0.05, therefore fail to reject the null hypothesis. So, candidate is able to do more than 5 push-ups

# %% [markdown]
# #### Problem 7:
#
#
#
# #### Dental implant data: The hardness of metal implant in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as on the dentists who may favour one method above another and may work better in his/her favourite method. The response is the variable of interest.
#
# #### 7.1 Test whether there is any difference among the dentists on the implant hardness. State the null and alternative hypotheses. Note that both types of alloys cannot be considered together. You must state the null and alternative hypotheses separately for the two types of alloys.?

# %%
df7 = pd.read_excel('Dental Hardness data.xlsx', sheet_name='Data')
df7
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 0         1       1      1  1500       813
# 1         1       1      1  1600       792
# 2         1       1      1  1700       792
# 3         1       1      2  1500       907
# 4         1       1      2  1600       792
# ..      ...     ...    ...   ...       ...
# 85        5       3      1  1600       483
# 86        5       3      1  1700       405
# 87        5       3      2  1500       536
# 88        5       3      2  1600       405
# 89        5       3      2  1700       312
#
# [90 rows x 5 columns]

# %%
df7.head(40)
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 0         1       1      1  1500       813
# 1         1       1      1  1600       792
# 2         1       1      1  1700       792
# 3         1       1      2  1500       907
# 4         1       1      2  1600       792
# 5         1       1      2  1700       835
# 6         1       2      1  1500       782
# 7         1       2      1  1600       698
# 8         1       2      1  1700       665
# 9         1       2      2  1500      1115
# 10        1       2      2  1600       835
# 11        1       2      2  1700       870
# 12        1       3      1  1500       752
# 13        1       3      1  1600       620
# 14        1       3      1  1700       835
# 15        1       3      2  1500       847
# 16        1       3      2  1600       560
# 17        1       3      2  1700       585
# 18        2       1      1  1500       715
# 19        2       1      1  1600       803
# 20        2       1      1  1700       813
# ...

# %%
df7.tail()
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 85        5       3      1  1600       483
# 86        5       3      1  1700       405
# 87        5       3      2  1500       536
# 88        5       3      2  1600       405
# 89        5       3      2  1700       312

# %%
df7.describe()
# Out:
#          Dentist     Method      Alloy         Temp     Response
# count  90.000000  90.000000  90.000000    90.000000    90.000000
# mean    3.000000   2.000000   1.500000  1600.000000   741.777778
# std     1.422136   0.821071   0.502801    82.107083   145.767845
# min     1.000000   1.000000   1.000000  1500.000000   289.000000
# 25%     2.000000   1.000000   1.000000  1500.000000   698.000000
# 50%     3.000000   2.000000   1.500000  1600.000000   767.000000
# 75%     4.000000   3.000000   2.000000  1700.000000   824.000000
# max     5.000000   3.000000   2.000000  1700.000000  1115.000000

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
df7.Dentist = pd.Categorical(df7.Dentist)

# %%
df7.Dentist.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 85    5
# 86    5
# 87    5
# 88    5
# 89    5
# Name: Dentist, Length: 90, dtype: category
# Categories (5, int64): [1, 2, 3, 4, 5]>

# %%
df7.Method = pd.Categorical(df7.Method)

# %%
df7.Method.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 85    3
# 86    3
# 87    3
# 88    3
# 89    3
# Name: Method, Length: 90, dtype: category
# Categories (3, int64): [1, 2, 3]>

# %%
df7.Alloy = pd.Categorical(df7.Alloy)

# %%
df7.Alloy.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 3     2
# 4     2
#      ..
# 85    1
# 86    1
# 87    2
# 88    2
# 89    2
# Name: Alloy, Length: 90, dtype: category
# Categories (2, int64): [1, 2]>

# %%
Alloy_1 = df7[df7['Alloy']==1]
Alloy_1
# Out:
#    Dentist Method Alloy  Temp  Response
# 0        1      1     1  1500       813
# 1        1      1     1  1600       792
# 2        1      1     1  1700       792
# 6        1      2     1  1500       782
# 7        1      2     1  1600       698
# 8        1      2     1  1700       665
# 12       1      3     1  1500       752
# 13       1      3     1  1600       620
# 14       1      3     1  1700       835
# 18       2      1     1  1500       715
# 19       2      1     1  1600       803
# 20       2      1     1  1700       813
# 24       2      2     1  1500       772
# 25       2      2     1  1600       782
# 26       2      2     1  1700       743
# 30       2      3     1  1500       835
# 31       2      3     1  1600       715
# 32       2      3     1  1700       673
# 36       3      1     1  1500       743
# 37       3      1     1  1600       627
# 38       3      1     1  1700       752
# 42       3      2     1  1500       813
# ...

# %%
Alloy_2 = df7[df7['Alloy']==2]
Alloy_2
# Out:
#    Dentist Method Alloy  Temp  Response
# 3        1      1     2  1500       907
# 4        1      1     2  1600       792
# 5        1      1     2  1700       835
# 9        1      2     2  1500      1115
# 10       1      2     2  1600       835
# 11       1      2     2  1700       870
# 15       1      3     2  1500       847
# 16       1      3     2  1600       560
# 17       1      3     2  1700       585
# 21       2      1     2  1500       858
# 22       2      1     2  1600       907
# 23       2      1     2  1700       882
# 27       2      2     2  1500       933
# 28       2      2     2  1600       792
# 29       2      2     2  1700       824
# 33       2      3     2  1500       698
# 34       2      3     2  1600       734
# 35       2      3     2  1700       681
# 39       3      1     2  1500       858
# 40       3      1     2  1600       762
# 41       3      1     2  1700       724
# 45       3      2     2  1500       824
# ...

# %% [markdown]
# #### H0= there is no difference among the dentists on the implant hardness
# #### H1= there is difference among the dentists on the implant hardness

# %%
from statsmodels.formula.api import ols     
from statsmodels.stats.anova import _get_covariance,anova_lm

# %%
formula = 'Response ~ C(Dentist)'
model = ols(formula, df7).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  1.577946e+05  39448.638889  1.934537  0.112066
# Residual    85.0  1.733301e+06  20391.776471       NaN       NaN

# %% [markdown]
# #### Based on the ANOVA test we, therefore, fail to reject the null hypothesis that there is no difference among the dentists on the implant hardness.

# %% [markdown]
# #### Alloy_1
# #### H0 = there is no difference among the dentists on the implant hardness for Alloy1
# #### H1= there is difference among the dentists on the implant hardness for Alloy1

# %%
formula = 'Response ~ C(Dentist) + C(Alloy)'
model = ols(formula, Alloy_1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# C(Alloy)     1.0    8109.831591   8109.831591  0.601181  0.442688
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %% [markdown]
# #### Since the p-values for Dentist and Alloy are both greater than .05,therefore,we fail to reject the null hypothesis. this means that both factors have a no statistically significant difference.

# %% [markdown]
# #### Alloy_2
# #### H0 = there is no difference among the dentists on the implant hardness for Alloy2
# #### H1= there is difference among the dentists on the implant hardness for Alloy2

# %%
formula = 'Response ~ C(Dentist) + C(Alloy)'
model = ols(formula, Alloy_2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# C(Alloy)     1.0  9.270681e+03   9270.680556  0.342659  0.561587
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %% [markdown]
# #### Since the p-values for Dentist and Alloy2 are both greater than 0.05,therefore, fail to reject the null hypothesis. this means that both factors have no statistically significant difference.

# %% [markdown]
# #### 7.3 Irrespective of your conclusion in 2, we will continue with the testing procedure. What do you conclude regarding whether implant hardness depends on dentists? Clearly state your conclusion. If the null hypothesis is rejected, is it possible to identify which pairs of dentists differ?

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison 
MultiComp=MultiComparison(Alloy_1['Response'],Alloy_1['Dentist'])
print(MultiComp.tukeyhsd().summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   11.3333 0.9996 -145.0423  167.709  False
#      1      3  -32.3333 0.9757  -188.709 124.0423  False
#      1      4  -68.7778 0.7189 -225.1535  87.5979  False
#      1      5 -122.2222 0.1889 -278.5979  34.1535  False
#      2      3  -43.6667 0.9298 -200.0423  112.709  False
#      2      4  -80.1111 0.5916 -236.4868  76.2646  False
#      2      5 -133.5556 0.1258 -289.9312  22.8201  False
#      3      4  -36.4444 0.9626 -192.8201 119.9312  False
#      3      5  -89.8889 0.4805 -246.2646  66.4868  False
#      4      5  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %% [markdown]
# #### From the above result, all the P value are greater than 0.05,All the pair of destist 1,2,3,4,5 has no significant difference for alloy1

# %%
MultiComp=MultiComparison(Alloy_2['Response'],Alloy_2['Dentist'])
print(MultiComp.tukeyhsd().summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      1      2  -4.1111    1.0 -225.5687 217.3465  False
#      1      3 -36.5556 0.9895 -258.0131  184.902  False
#      1      4    -70.0 0.8941 -291.4576 151.4576  False
#      1      5 -90.1111 0.7724 -311.5687 131.3465  False
#      2      3 -32.4444 0.9933  -253.902 189.0131  False
#      2      4 -65.8889 0.9132 -287.3465 155.5687  False
#      2      5    -86.0 0.8008 -307.4576 135.4576  False
#      3      4 -33.4444 0.9925  -254.902 188.0131  False
#      3      5 -53.5556 0.9574 -275.0131  167.902  False
#      4      5 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %% [markdown]
# #### From the above result, all the P value are greater than 0.05,All the pair of destist 1,2,3,4,5 has no significant difference for alloy2. So all dentist has no difference

# %% [markdown]
# #### 7.4 Now test whether there is any difference among the methods on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which pairs of methods differ?

# %% [markdown]
# #### Alloy_1
# #### H0= there is no difference among the method on the hardness of dental implant
# #### H1= there is difference among the method on the hardness of dental implant

# %%
formula = 'Response ~ C(Method) + C(Alloy)'
model = ols(formula, Alloy_1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# C(Alloy)    1.0    1259.607624   1259.607624  0.106274  0.746046
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %%
model = ols(formula, Alloy_1).fit()
model.summary()
# Out:
# E:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1918: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Response   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     6.263
# Date:                Mon, 03 Apr 2023   Prob (F-statistic):            0.00416
# Time:                        20:08:50   Log-Likelihood:                -273.36
# No. Observations:                  45   AIC:                             552.7
# Df Residuals:                      42   BIC:                             558.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# #### Since the p-values for Method was less than 0.05 and Alloy were greater than .05,therefore,we reject the null hypothesis. The F-statistic= 6.263 and the p-value= 0.004163 which is indicating that there is an overall significant effect of Method on imlant hardness. However, we don’t know where the difference between Method is yet. So, based on the p-value we can reject the H0; that is there’s no significant difference.

# %%
formula = 'Response ~ C(Method) + C(Alloy)'
model = ols(formula, Alloy_2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#              df         sum_sq        mean_sq          F    PR(>F)
# C(Method)   2.0  499640.400000  249820.200000  16.410800  0.000005
# C(Alloy)    1.0    5300.119048    5300.119048   0.348167  0.558314
# Residual   42.0  639362.400000   15222.914286        NaN       NaN

# %% [markdown]
# #### For alloy2, Since the p-values for Method was less than 0.05 and Alloy were greater than .05,therefore,we reject the null hypothesis. The F-statistic= 16.4 and the p-value= 0.000005 which is indicating that there is an overall significant effect of Method on imlant hardness. However, we don’t know where the difference between Method is yet. So, based on the p-value we can reject the H0; that is there’s no significant difference.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison  
MultiComp=MultiComparison(Alloy_1['Response'],Alloy_1['Method'])
print(MultiComp.tukeyhsd().summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %% [markdown]
# #### P-value  is significant  for comparing methods mean levels for  the pair method 1  and method 2 and method 3, but not for method 1 and method 2. The null hypothesis  is rejected. It is now clear that mean method 1 and method 2 is similar but method 3 is significantly different from these two for alloy1.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison  
MultiComp=MultiComparison(Alloy_2['Response'],Alloy_2['Method'])
print(MultiComp.tukeyhsd().summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %% [markdown]
# #### P-value is significant for comparing methods mean levels for the pair method 1 and method 2 and method 3, but not for method 1 and method 2. The null hypothesis is rejected. It is now clear that mean method 1 and method 2 is similar but method 3 is significantly different from these two for alloy 2.

# %% [markdown]
# #### 7.5Now test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which levels of temperatures differ?
# #### Alloy_1
# #### H0= there is no difference among the temperature on the hardness of dental implant
# #### H1= there is difference among the temperature on the hardness of dental implant

# %%
formula = 'Response ~ C(Temp) + C(Alloy)'
model = ols(formula, Alloy_1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#             df         sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0   10154.444444   5077.222222  0.335224  0.717074
# C(Alloy)   1.0    4055.642845   4055.642845  0.267774  0.607544
# Residual  42.0  636122.800000  15145.780952       NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison  
MultiComp=MultiComparison(Alloy_1['Response'],Alloy_1['Temp'])
print(MultiComp.tukeyhsd().summary())
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper  reject
# ------------------------------------------------------
#   1500   1600 -15.6667 0.9353 -124.8436 93.5103  False
#   1500   1700 -36.6667 0.6953 -145.8436 72.5103  False
#   1600   1700    -21.0 0.8869  -130.177  88.177  False
# ------------------------------------------------------

# %% [markdown]
# #### From the above result, all the P value are greater than 0.05,All the pair of temperature has no significant difference for alloy1. No difference. Fail to reject the null hypothesis

# %% [markdown]
# #### Alloy_2
# #### H0= there is no difference among the temperature on the hardness of dental implant
# #### H1= there is difference among the temperature on the hardness of dental implant

# %%
formula = 'Response ~ C(Temp) + C(Alloy)'
model = ols(formula, Alloy_2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#             df        sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0  9.374893e+04  46874.466667  1.883492  0.164678
# C(Alloy)   1.0  7.998171e+03   7998.171429  0.321380  0.573797
# Residual  42.0  1.045254e+06  24886.996825       NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison  
MultiComp=MultiComparison(Alloy_2['Response'],Alloy_2['Temp'])
print(MultiComp.tukeyhsd().summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#   1500   1600  -26.3333 0.8915 -166.2828 113.6162  False
#   1500   1700 -107.2667 0.1624 -247.2162  32.6828  False
#   1600   1700  -80.9333 0.3475 -220.8828  59.0162  False
# --------------------------------------------------------

# %% [markdown]
# #### From the above result, all the P value are greater than 0.05,All the pair of temperature has no significant difference for alloy2. No difference. Fail to reject the null hypothesis

# %% [markdown]
# #### 7.6 Consider the interaction effect of dentist and method and comment on the interaction plot, separately for the two types of alloys?

# %%
sns.pointplot(x='Dentist', y='Response', data=Alloy_1, hue='Method',ci=None);

# %%
sns.pointplot(x='Dentist', y='Response', data=Alloy_2, hue='Method',ci=None);
